# %%
state = 0
if 1 == state:
    import pandas_datareader as pdr
    import datetime
    import yfinance as yf
    yf.pdr_override()
    from pandas_datareader import data as pdr
    df = pdr.get_data_yahoo('^GSPC', start = start_date, end = end_date)
    df.reset_index(inplace=True)
    df.to_csv("data/sp500.csv",index=False)

# %% [markdown]
# # Import Module

# %%
from yahoo_fin import stock_info
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import pickle

# %% [markdown]
# # Download ticker symbols for sp500

# %%
# # gather stock symbols from major US exchanges
# df_sp = pd.DataFrame(stock_info.tickers_sp500())
# # rename column
# df_sp.columns = ["ticker"]
# #df2 = pd.DataFrame(stock_info.tickers_nasdaq())
# #df3 = pd.DataFrame(stock_info.tickers_dow())
# #df4 = pd.DataFrame(stock_info.tickers_other())

df = pd.read_csv('data\sp500.csv')
df_sp= pd.DataFrame(df["Symbol"])
df_sp.rename(columns = {'Symbol':'ticker'}, inplace = True)
df_sp.sort_values(by = 'ticker',ascending = True, inplace = True)
df_sp.head(10)
# Out:
#    ticker
# 14      A
# 32    AAL
# 8     AAP
# 51   AAPL
# 3    ABBV
# 39    ABC
# 2     ABT
# 4     ACN
# 7    ADBE
# 44    ADI

# %%
df_sp.to_csv("data/sp500_ticker.csv", index = False)

# %%
ticker = df_sp["ticker"].iloc[0]
ticker = 'A'
stock_price = yf.download(ticker, period="max")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
stock_price
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1999-11-18   32.546494   35.765381   28.612303   31.473534   26.695696
# 1999-11-19   30.713518   30.758226   28.478184   28.880545   24.496338
# 1999-11-22   29.551144   31.473534   28.657009   31.473534   26.695696
# 1999-11-23   30.400572   31.205294   28.612303   28.612303   24.268814
# 1999-11-24   28.701717   29.998213   28.612303   29.372318   24.913458
# ...                ...         ...         ...         ...         ...
# 2023-12-29  139.070007  139.699997  138.360001  139.029999  139.029999
# 2024-01-02  138.190002  140.589996  137.910004  138.750000  138.750000
# 2024-01-03  138.000000  138.000000  131.070007  131.160004  131.160004
# 2024-01-04  130.550003  131.500000  130.190002  131.000000  131.000000
# 2024-01-05  130.000000  131.960007  128.619995  130.559998  130.559998
#
#               Volume
# Date
# 1999-11-18  62546380
# 1999-11-19  15234146
# 1999-11-22   6577870
# 1999-11-23   5975611
# 1999-11-24   4843231
# ...              ...
# 2023-12-29   1014400
# 2024-01-02   1441600
# 2024-01-03   2074500
# 2024-01-04   2446600
# 2024-01-05   1394000
#
# [6071 rows x 6 columns]

# %%
plt.plot(stock_price["Adj Close"], color = "k")
plt.xlabel("time", size = 14)
plt.ylabel("USD", size =14)
# Out:
# Text(0, 0.5, 'USD')

# %%
ticker = 'nvda'
print(ticker)
stock_price = yf.download(ticker, period = 'max')
stock_price.head(10)
# Out:
# nvda
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 1999-01-22  0.437500  0.488281  0.388021  0.410156   0.376255  271468800
# 1999-01-25  0.442708  0.458333  0.410156  0.453125   0.415672   51048000
# 1999-01-26  0.458333  0.467448  0.411458  0.417969   0.383422   34320000
# 1999-01-27  0.419271  0.429688  0.395833  0.416667   0.382227   24436800
# 1999-01-28  0.416667  0.419271  0.412760  0.415365   0.381033   22752000
# 1999-01-29  0.415365  0.416667  0.395833  0.395833   0.363115   24403200
# 1999-02-01  0.395833  0.406250  0.395833  0.403646   0.370283   15470400
# 1999-02-02  0.395833  0.406250  0.360677  0.372396   0.341616   26409600
# 1999-02-03  0.367188  0.385417  0.364583  0.380208   0.348782    7512000
# 1999-02-04  0.385417  0.411458  0.380208  0.401042   0.367894   18192000

# %%
plt.plot(stock_price["Adj Close"], color = 'k')
plt.xlabel("Time", size = 14)
plt.ylabel("USD", size = 14)
plt.title("Stock Price of Nvidia")
# Out:
# Text(0.5, 1.0, 'Stock Price of Nvidia')

# %%
df_sp
# Out:
#     ticker
# 14       A
# 32     AAL
# 8      AAP
# 51    AAPL
# 3     ABBV
# ..     ...
# 500    XYL
# 501    YUM
# 502    ZBH
# 503   ZION
# 504    ZTS
#
# [505 rows x 1 columns]

# %%
# %%time
# list_stock = []
# # If you want you can download the entire SP500 
# #for kkk in range(len(df_sp)):
# for item in range(len(df_sp)):
#     ticker = df_sp["ticker"].iloc[item]
#     print(ticker)
#     stock_price = yf.download(ticker, period="max")
#     stock_price["ticker"] = ticker   
#     list_stock.append(stock_price)
    
# df_stock = pd.concat(list_stock)

# %%
# ticker = "^GSPC"
ticker = "4519.T"
df = yf.download(ticker, period = "max")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-04  368.333344  368.333344  363.000000  366.666656  248.354126
# 2000-01-05  366.666656  373.333344  360.333344  373.333344  252.869507
# 2000-01-06  393.333344  436.666656  393.333344  431.000000  291.928864
# 2000-01-07  438.333344  445.000000  420.000000  441.000000  298.702209
# 2000-01-10  441.000000  441.000000  441.000000  441.000000  298.702209
#
#               Volume
# Date
# 2000-01-04    768000
# 2000-01-05   1371000
# 2000-01-06   8613000
# 2000-01-07  11655000
# 2000-01-10         0

# %%
plt.plot(df["Adj Close"], color = "k")
plt.xlabel("time", size = 14)
plt.ylabel("USD", size =14)
# Out:
# Text(0, 0.5, 'USD')

# %%
# ticker = "^GSPC"
ticker = "4519.T"
df = yf.download(ticker, period = "max")
# Calculate return
df['Return'] = np.log(df['Adj Close'] / df['Adj Close'].shift(1))
# This is another way to calculate return
#df['Return'] = df["Adj Close"].pct_change(1).mul(100)
# df["shift"] = df['Adj Close'].shift(1)
df["Volatility"] = df.Return.abs()

# # Drop NA
df.dropna(inplace=True)
df.head(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-05  366.666656  373.333344  360.333344  373.333344  252.869629
# 2000-01-06  393.333344  436.666656  393.333344  431.000000  291.928955
# 2000-01-07  438.333344  445.000000  420.000000  441.000000  298.702026
# 2000-01-10  441.000000  441.000000  441.000000  441.000000  298.702026
# 2000-01-11  441.000000  441.000000  417.666656  430.666656  291.703094
# 2000-01-12  430.666656  447.000000  424.000000  435.000000  294.638123
# 2000-01-13  468.333344  496.666656  463.333344  476.666656  322.860229
# 2000-01-14  490.000000  508.333344  480.000000  498.333344  337.535736
# 2000-01-17  510.000000  520.000000  500.000000  507.333344  343.631653
# 2000-01-18  503.666656  503.666656  485.000000  498.666656  337.761475
#
#               Volume    Return  Volatility
# Date
# 2000-01-05   1371000  0.018019    0.018019
# 2000-01-06   8613000  0.143636    0.143636
# 2000-01-07  11655000  0.022936    0.022936
# 2000-01-10         0  0.000000    0.000000
# 2000-01-11   3576000 -0.023710    0.023710
# 2000-01-12   4428000  0.010011    0.010011
# 2000-01-13  15633000  0.091472    0.091472
# 2000-01-14  13698000  0.044452    0.044452
# 2000-01-17  10434000  0.017899    0.017899
# 2000-01-18   5331000 -0.017230    0.017230

# %%
plt.figure(figsize = (8,4))
plt.plot(df["Return"], color = 'k')
plt.xlabel("Time", size = 14)
plt.ylabel("USD", size =14)
# Out:
# Text(0, 0.5, 'USD')

# %%
plt.figure(figsize = (8,4))
plt.plot(df["Volatility"], color = 'k')
plt.xlabel("Time", size = 14)
plt.ylabel("USD", size =14)
# Out:
# Text(0, 0.5, 'USD')

# %%
# Moving average of Adjusted close
plt.figure(figsize=(8,4))
plt.plot(df["Adj Close"].rolling(window=360).mean(), color = "k")

# Moving average of Return
plt.figure(figsize=(8,4))
plt.plot(df["Return"].rolling(window=360).mean(), color = "k")

# Moving average of Volatiliy
plt.figure(figsize=(8,4))
plt.plot(df["Volatility"].rolling(window=360).mean(), color = "k")
len(df["Adj Close"])
# Out:
# 6004

# %%
len(df["Adj Close"].rolling(window=360).mean())
# Out:
# 6004

# %%
# Importing the required packages
from statsmodels.graphics.tsaplots import plot_acf

# plot autocorrelation of return
plot_acf(df["Return"], zero = True, lags = 30)
plt.show()

# %%
# plot autocorrelation of return
plot_acf(df["Return"].iloc[-5000:], zero = True, lags = 30)
plt.show()

# %%
# plot auto correlation for 
plot_acf(df["Volatility"], zero = True, lags = 50)
plt.show()

# %%
from scipy import interpolate
# Create column of Return with lag -1
df["ShiftReturn"] = df["Return"].shift(1)
df.dropna(inplace=True)

# %%
# sort dataframe using Return in ascending order 
df.sort_values(by="Return",ascending=True,inplace=True)

# to make life easier
x = df["Return"]
y = df["ShiftReturn"]

# %%
# Plot 
# set figure size
plt.figure(figsize=(8, 6))
# set title
plt.title("Return today vs Return tomorrow")
# plot scatter
plt.plot(x, y, '.', c="grey", label="original")

x1 = np.linspace(-0.2,0.2,1000)
y1 = np.linspace(-0.2,0.2,1000)

plt.plot(x1, y1)

# set x label and y label
plt.xlabel("today",size=14)
plt.ylabel("tomorrow",size=14)
# add grid
plt.grid()
# show
plt.show()

# %%
import statsmodels.api as sm
# stats model
reg_linear = sm.OLS(y, x)
result = reg_linear.fit()
# prediction
y_linear = result.predict(x)

# %%
# Plot: set figure size
plt.figure(figsize=(8, 6))
# set title
plt.title("Return today vs Return tomorrow")
# plot scatter
plt.plot(x, y, '.', c="grey", label="original")
# plot spline fit
plt.plot(x, y_linear, '-', c="g", label="linear fit")
# plot legend
plt.legend(loc='best', fancybox=True, shadow=True)
# set x label and y label
plt.xlabel("today",size=14)
plt.ylabel("tomorrow",size=14)
# add grid
plt.grid()
# show
plt.show()

# %% [markdown]
# # Spline

# %%
# number of nots
# Avoid error related to the Schoenberg-Whitney conditions
knot_numbers = 15

# we place nots using quantiles
x_quantile = np.linspace(0, 1, knot_numbers+2)[1:-1]
q_knots = np.quantile(x, x_quantile) 

x_min = np.quantile(x,0.001)
x_max = np.quantile(x,0.999)
x_new = np.linspace(x_min, x_max, 500)

#df_xy = pd.DataFrame({"x":x, "y":y})
#df_xy.drop_duplicates(inplace=True)

# %%
# Interpolate using splines
t,c,k = interpolate.splrep(x, y, t=q_knots, s=1)
yfit = interpolate.BSpline(t,c,k)(x_new)

# %%
# Plot 
# set figure size
plt.figure(figsize=(8, 6))
# set title
plt.title("Return today vs Return tomorrow")
# plot scatter
plt.plot(x, y, '.', c="grey", label="original")
# plot spline fit
plt.plot(x_new, yfit, '-', c="g", label="spline fit")
# plot legend
plt.legend(loc='best', fancybox=True, shadow=True)
# set x limits
plt.xlim(x_min,x_max)
# set x label and y label
plt.xlabel("today",size=14)
plt.ylabel("tomorrow",size=14)
# add grid
plt.grid()
# show
plt.show()

# %%
# Initialize matices to store result
Yfit = np.zeros(shape=(1000,yfit.shape[0]))
y_lower = np.zeros(shape=yfit.shape[0])
y_upper = np.zeros(shape=yfit.shape[0])

# %%
# %%time
# Create 1000 Bootstrapped samples
for i in range(1000):

    # Random sample with replacements
    df_sample = df.iloc[np.random.randint(0, len(df), size=len(df))]
    
    # Sort
    df_sample.sort_values(by="Return",ascending=True,inplace=True)
    
    # xaxis is the return today
    x = df_sample["Return"]
    # yaxis is the return tomorrow
    y = df_sample["ShiftReturn"]

    # interplate using B soline
    t,c,k = interpolate.splrep(x, y, t=q_knots, s=1)
    yfit = interpolate.BSpline(t,c,k)(x_new) 
    
    # store result
    Yfit[i,:] = yfit
# Out:
# CPU times: total: 312 ms
# Wall time: 1.33 s

# %%
# Calculate upper and lower confidence interval
for i in range(yfit.shape[0]):
    y_lower[i] = np.quantile(Yfit[:,i],0.01)
    y_upper[i] = np.quantile(Yfit[:,i],0.99)

# %%
# Plot 
plt.figure(figsize=(8, 6))
plt.title("Return today vs Return tomorrow")
plt.plot(x, y, '.', c="grey", label="original")
plt.plot(x_new, y_upper, '-', c="b", label="upper 0.99")
plt.plot(x_new, y_lower, '-', c="r", label="lower 0.01")
plt.legend(loc='best', fancybox=True, shadow=True)
plt.xlim(x_min,x_max)
plt.xlabel("today",size=14)
plt.ylabel("tomorrow",size=14)
plt.grid()
plt.show()

# %% [markdown]
# # Anomaly detection

# %%
# Resort the dataframe
df.sort_values(by="Date",ascending=True,inplace=True)

# %%
# Calculate the moving average and standard deviation
window_size = 90
df['Moving Average'] = df["Return"].rolling(window=window_size).mean()
df['Standard Deviation'] = df['Return'].rolling(window=window_size).std()
df.dropna(inplace=True)

# %%
# Set the threshold for anomaly detection
threshold = 4.5
df['Lower Bound'] = df['Moving Average'] - (df['Standard Deviation'] * threshold)
df['Upper Bound'] = df['Moving Average'] + (df['Standard Deviation'] * threshold)

# Identify the anomalies
df['Anomaly'] = np.where((df['Return'] > df['Upper Bound']) | (df['Return'] < df['Lower Bound']), 1, 0)

# %%
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-09-12   620.666687   620.666687   614.666687   614.666687   416.655640
# 2000-09-13   624.666687   624.666687   615.000000   618.333313   419.141144
# 2000-09-14   620.000000   621.000000   600.000000   606.666687   411.232758
# 2000-09-15   606.666687   606.666687   606.666687   606.666687   411.232758
# 2000-09-18   615.666687   615.666687   607.666687   611.333313   414.396179
# ...                 ...          ...          ...          ...          ...
# 2023-12-27  5357.000000  5423.000000  5330.000000  5384.000000  5344.000000
# 2023-12-28  5344.000000  5401.000000  5298.000000  5386.000000  5386.000000
# 2023-12-29  5373.000000  5414.000000  5295.000000  5342.000000  5342.000000
# 2024-01-04  5307.000000  5380.000000  5247.000000  5380.000000  5380.000000
# 2024-01-05  5398.000000  5428.000000  5366.000000  5388.000000  5388.000000
#
#              Volume    Return  Volatility  ShiftReturn  Moving Average  \
# Date
# 2000-09-12  1056000 -0.010251    0.010251    -0.011209       -0.002162
# 2000-09-13  1524000  0.005948    0.005948    -0.010251       -0.001971
# 2000-09-14  1302000 -0.019048    0.019048     0.005948       -0.001774
# 2000-09-15        0  0.000000    0.000000    -0.019048       -0.002157
# 2000-09-18  1269000  0.007663    0.007663     0.000000       -0.001996
# ...             ...       ...         ...          ...             ...
# 2023-12-27  1932400  0.005401    0.005401     0.001121        0.002573
# 2023-12-28  1051400  0.007829    0.007829     0.005401        0.002807
# 2023-12-29  1603000 -0.008203    0.008203     0.007829        0.002681
# 2024-01-04  2277300  0.007088    0.007088    -0.008203        0.002760
# 2024-01-05  1757900  0.001486    0.001486     0.007088        0.002743
#
#             Standard Deviation  Lower Bound  Upper Bound  Anomaly
# Date
# 2000-09-12            0.021110    -0.097155     0.092832        0
# 2000-09-13            0.021104    -0.096941     0.092999        0
# 2000-09-14            0.020857    -0.095631     0.092083        0
# 2000-09-15            0.020496    -0.094391     0.090076        0
# 2000-09-18            0.020516    -0.094319     0.090326        0
# ...                        ...          ...          ...      ...
# 2023-12-27            0.016322    -0.070875     0.076022        0
# 2023-12-28            0.016244    -0.070291     0.075904        0
# 2023-12-29            0.016285    -0.070602     0.075965        0
# 2024-01-04            0.016289    -0.070542     0.076062        0
# 2024-01-05            0.016290    -0.070561     0.076047        0
#
# [5825 rows x 14 columns]

# %% [markdown]
# # Visualize Results

# %%
# Set the threshold for anomaly detection
threshold = 4.5
df['Lower Bound'] = df['Moving Average'] - (df['Standard Deviation'] * threshold)
df['Upper Bound'] = df['Moving Average'] + (df['Standard Deviation'] * threshold)

# Identify the anomalies
df['Anomaly'] = np.where((df['Return'] > df['Upper Bound']) | (df['Return'] < df['Lower Bound']), 1, 0)
