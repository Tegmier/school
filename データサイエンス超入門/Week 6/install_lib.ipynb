# %%
# !pip install albumentations
# !pip install matplotlib
# !pip install numpy
# !pip install opencv-python
# !pip install opencv-contrib-python
# !pip install pillow
# !pip install pyyaml
# !pip install scikit-learn
# !pip install torch
# !pip install torchvision
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting albumentations
#   Using cached albumentations-1.3.0-py3-none-any.whl (123 kB)
# Requirement already satisfied: numpy>=1.11.1 in /home/kondo/.local/lib/python3.8/site-packages (from albumentations) (1.24.2)
# Requirement already satisfied: scipy in /usr/lib/python3/dist-packages (from albumentations) (1.8.0)
# Collecting scikit-image>=0.16.1 (from albumentations)
#   Downloading scikit_image-0.20.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 56.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: PyYAML in /usr/lib/python3/dist-packages (from albumentations) (5.4.1)
# Collecting qudida>=0.0.4 (from albumentations)
#   Using cached qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Collecting opencv-python-headless>=4.1.1 (from albumentations)
#   Using cached opencv_python_headless-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
# Collecting scikit-learn>=0.19.1 (from qudida>=0.0.4->albumentations)
#   Downloading scikit_learn-1.2.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 78.5 MB/s eta 0:00:00:00:0100:01
# Collecting typing-extensions (from qudida>=0.0.4->albumentations)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting networkx>=2.8 (from scikit-image>=0.16.1->albumentations)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=9.0.1 in /usr/lib/python3/dist-packages (from scikit-image>=0.16.1->albumentations) (9.0.1)
# Collecting imageio>=2.4.1 (from scikit-image>=0.16.1->albumentations)
#   Downloading imageio-2.28.1-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 67.7 MB/s eta 0:00:00:00:01
# Collecting tifffile>=2019.7.26 (from scikit-image>=0.16.1->albumentations)
#   Downloading tifffile-2023.4.12-py3-none-any.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.4/219.4 kB 33.3 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1 (from scikit-image>=0.16.1->albumentations)
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 81.2 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from scikit-image>=0.16.1->albumentations) (21.3)
# Collecting lazy_loader>=0.1 (from scikit-image>=0.16.1->albumentations)
#   Using cached lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Collecting joblib>=1.1.1 (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations)
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations)
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: typing-extensions, tifffile, threadpoolctl, PyWavelets, opencv-python-headless, networkx, lazy_loader, joblib, imageio, scikit-learn, scikit-image, qudida, albumentations
# Successfully installed PyWavelets-1.4.1 albumentations-1.3.0 imageio-2.28.1 joblib-1.2.0 lazy_loader-0.2 networkx-3.1 opencv-python-headless-4.7.0.72 qudida-0.0.4 scikit-image-0.20.0 scikit-learn-1.2.2 threadpoolctl-3.1.0 tifffile-2023.4.12 typing-extensions-4.5.0
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (3.5.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /home/kondo/.local/lib/python3.8/site-packages (1.24.2)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 13.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.17.0 in /home/kondo/.local/lib/python3.8/site-packages (from opencv-python) (1.24.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-contrib-python
#   Using cached opencv_contrib_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67.9 MB)
# Requirement already satisfied: numpy>=1.17.0 in /home/kondo/.local/lib/python3.8/site-packages (from opencv-contrib-python) (1.24.2)
# Installing collected packages: opencv-contrib-python
# Successfully installed opencv-contrib-python-4.7.0.72
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (9.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (5.4.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/kondo/.local/lib/python3.8/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/kondo/.local/lib/python3.8/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/lib/python3/dist-packages (from scikit-learn) (1.8.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/kondo/.local/lib/python3.8/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/kondo/.local/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.0.1-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB ? eta 0:00:000:00:0100:02
# Collecting filelock (from torch)
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /home/kondo/.local/lib/python3.8/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch) (1.9)
# Requirement already satisfied: networkx in /home/kondo/.local/lib/python3.8/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch) (3.0.3)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch)
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch)
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch)
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch)
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch)
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch)
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch)
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch)
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch)
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch)
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting triton==2.0.0 (from torch)
#   Downloading triton-2.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 MB 9.9 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (59.6.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Collecting cmake (from triton==2.0.0->torch)
#   Downloading cmake-3.26.3-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 34.4 MB/s eta 0:00:0000:0100:01
# Collecting lit (from triton==2.0.0->torch)
#   Downloading lit-16.0.3.tar.gz (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-16.0.3-py3-none-any.whl size=88195 sha256=22afdfe4bd2a8c33e045b7d53418121d3b94a386842ae03b74db1d6d2dc2a814
#   Stored in directory: /home/kondo/.cache/pip/wheels/01/20/c2/b32a74e477abe541734225f8d5ed8b9e284d1f8580f6828445
# Successfully built lit
# Installing collected packages: lit, cmake, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, filelock, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch
# Successfully installed cmake-3.26.3 filelock-3.12.0 lit-16.0.3 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 triton-2.0.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchvision
#   Downloading torchvision-0.15.2-cp38-cp38-manylinux1_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 7.6 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: numpy in /home/kondo/.local/lib/python3.8/site-packages (from torchvision) (1.24.2)
# Requirement already satisfied: requests in /home/kondo/.local/lib/python3.8/site-packages (from torchvision) (2.28.2)
# Requirement already satisfied: torch==2.0.1 in /home/kondo/.local/lib/python3.8/site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/lib/python3/dist-packages (from torchvision) (9.0.1)
# Requirement already satisfied: filelock in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch==2.0.1->torchvision) (1.9)
# Requirement already satisfied: networkx in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch==2.0.1->torchvision) (3.0.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/kondo/.local/lib/python3.8/site-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (59.6.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision) (0.37.1)
# Requirement already satisfied: cmake in /home/kondo/.local/lib/python3.8/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.26.3)
# Requirement already satisfied: lit in /home/kondo/.local/lib/python3.8/site-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kondo/.local/lib/python3.8/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/kondo/.local/lib/python3.8/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->torchvision) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kondo/.local/lib/python3.8/site-packages (from requests->torchvision) (2022.12.7)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.15.2
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tqdm
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.65.0
